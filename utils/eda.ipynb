# %%
import pandas as pd
import sqlite3

# %%
# Create a SQL connection to our SQLite database
con = sqlite3.connect("../data/mobile_devices.db")

cur = con.cursor()

t = cur.execute("SELECT * FROM sqlite_master WHERE type='table'")

t.fetchall()
# Out:
# [('table',
#   'mobile_device_specs',
#   'mobile_device_specs',
#   2,
#   'CREATE TABLE "mobile_device_specs" (\n"id" INTEGER,\n  "battery_power" INTEGER,\n  "blue" INTEGER,\n  "clock_speed" REAL,\n  "dual_sim" INTEGER,\n  "fc" INTEGER,\n  "four_g" INTEGER,\n  "int_memory" INTEGER,\n  "m_dep" REAL,\n  "mobile_wt" INTEGER,\n  "n_cores" INTEGER,\n  "pc" INTEGER,\n  "px_height" INTEGER,\n  "px_width" INTEGER,\n  "ram" INTEGER,\n  "sc_h" INTEGER,\n  "sc_w" INTEGER,\n  "talk_time" INTEGER,\n  "three_g" INTEGER,\n  "touch_screen" INTEGER,\n  "wifi" INTEGER,\n  "price_range" REAL\n)')]

# %%
df = pd.read_sql("SELECT * FROM mobile_device_specs", con=con)

# %%
df.sort_values('id')
# Out:
#         id  battery_power  blue  clock_speed  dual_sim  fc  four_g  \
# 0        0            842     0          2.2         0   1       0
# 2000     0           1043     1          1.8         1  14       0
# 1        1           1021     1          0.5         1   0       1
# 2001     1            841     1          0.5         1   4       1
# 2        2            563     1          0.5         1   2       1
# ...    ...            ...   ...          ...       ...  ..     ...
# 1995  1995            794     1          0.5         1   0       1
# 1996  1996           1965     1          2.6         1   0       0
# 1997  1997           1911     0          0.9         1   1       1
# 1998  1998           1512     0          0.9         0   4       1
# 1999  1999            510     1          2.0         1   5       1
#
#       int_memory  m_dep  mobile_wt  ...  px_height  px_width   ram  sc_h  \
# 0              7    0.6        188  ...         20       756  2549     9
# ...

# %%
df = pd.read_sql(sql='SELECT "id" FROM mobile_device_specs',con=con)

# %%
df.value_counts('id')

# %%
con.close()
